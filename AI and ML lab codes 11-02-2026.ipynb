# %%
import pandas as pd
import random
df = pd.DataFrame(data)

# %%
names = ["Aarav","Vihaan","Aditya","Kabir","Arjun","Rohan","Ishaan","Aryan","Kunal","Rahul",
         "Sneha","Ananya","Priya","Riya","Kavya","Meera","Nisha","Pooja","Shreya","Tanvi"]

data = {
    "Roll Number": [i for i in range(1, 51)],
    "Name": [random.choice(names) for _ in range(50)],
    "Height": [round(random.uniform(150, 190), 1) for _ in range(50)],
    "Weight": [round(random.uniform(45, 90), 1) for _ in range(50)],
    "Stipend": [random.randint(1000, 5000) for _ in range(50)]
}

# %%
f = pd.DataFrame(data)
print(df)
# Out:
#     Roll Number    Name  Height  Weight  Stipend
# 0             1   Kunal   151.0    74.9     3776
# 1             2  Vihaan   161.4    56.1     2521
# 2             3   Tanvi   170.4    74.9     4237
# 3             4   Arjun   186.0    50.4     4630
# 4             5   Aarav   182.5    45.3     2840
# 5             6   Arjun   161.8    64.3     4761
# 6             7   Aryan   158.0    76.7     1507
# 7             8  Shreya   182.1    77.6     2301
# 8             9   Rahul   155.4    49.9     2794
# 9            10  Ananya   150.2    54.5     2316
# 10           11  Shreya   158.1    53.9     4756
# 11           12   Aryan   172.5    86.4     1623
# 12           13  Aditya   163.2    89.0     1018
# 13           14  Shreya   178.1    78.4     3477
# 14           15    Riya   180.9    49.6     4817
# 15           16  Shreya   180.3    57.1     3844
# 16           17   Rahul   187.2    53.7     3777
# 17           18  Ishaan   172.6    56.1     2373
# ...

# %%
for col in ["Height","Weight","Stipend"]:
    df[col] = (df[col] - df[col].min()) / (df[col].max() - df[col].min())

print(df)
# Out:
#     Roll Number    Name    Height    Weight   Stipend
# 0             1   Kunal  0.022901  0.669683  0.725981
# 1             2  Vihaan  0.287532  0.244344  0.395630
# 2             3   Tanvi  0.516539  0.669683  0.847328
# 3             4   Arjun  0.913486  0.115385  0.950777
# 4             5   Aarav  0.824427  0.000000  0.479600
# 5             6   Arjun  0.297710  0.429864  0.985259
# 6             7   Aryan  0.201018  0.710407  0.128718
# 7             8  Shreya  0.814249  0.730769  0.337720
# 8             9   Rahul  0.134860  0.104072  0.467491
# 9            10  Ananya  0.002545  0.208145  0.341669
# 10           11  Shreya  0.203562  0.194570  0.983943
# 11           12   Aryan  0.569975  0.929864  0.159252
# 12           13  Aditya  0.333333  0.988688  0.000000
# 13           14  Shreya  0.712468  0.748869  0.647276
# 14           15    Riya  0.783715  0.097285  1.000000
# 15           16  Shreya  0.768448  0.266968  0.743880
# ...
